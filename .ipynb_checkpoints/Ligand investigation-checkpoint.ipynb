# %%
import pandas as pd
import numpy as np

hiv = pd.read_csv('hiv1-pr.csv')
pepsin = pd.read_csv('pepsinA.csv')

hiv_ligands = list(hiv['Ligand ID'])
pepsin_ligands = list(pepsin['Ligand ID'])

common_ligands = list(set(hiv_ligands).intersection(set(pepsin_ligands)))
common_ligands = [x for x in common_ligands if str(x) != 'nan']
print(common_ligands)

pepsin[pepsin['Ligand ID'].isin(common_ligands)]
# Out:
# ['EDO', 'NAG', 'DMS']
#    Entry ID Chain ID Ligand ID Ligand Formula  Ligand MW  \
# 0      1YX9        A       DMS      C2 H6 O S     78.133
# 14     6ORS        A       NAG    C8 H15 N O6    221.208
# 15      NaN        A       EDO       C2 H6 O2     62.068
#
#                                  Ligand Name  \
# 0                         DIMETHYL SULFOXIDE
# 14  2-acetamido-2-deoxy-beta-D-glucopyranose
# 15                            1,2-ETHANEDIOL
#
#                                                 InChI  \
# 0                     InChI=1S/C2H6OS/c1-4(2)3/h1-2H3
# 14  InChI=1S/C8H15NO6/c1-3(11)9-5-7(13)6(12)4(2-10...
# 15               InChI=1S/C2H6O2/c3-1-2-4/h3-4H,1-2H2
#
#                       InChI Key               Ligand SMILES  \
# 0   IAZDPXIOMUYVGZ-UHFFFAOYSA-N                     CS(=O)C
# 14  OVRNDRQMDRJTHS-FMDGEEDCSA-N  CC(=O)NC1C(C(C(OC1O)CO)O)O
# 15  LYCAIKOWRPUZTN-UHFFFAOYSA-N                      C(CO)O
#
#     Ligand of Interest  Unnamed: 10
# 0                  NaN          NaN
# 14                 NaN          NaN
# 15                 NaN          NaN
